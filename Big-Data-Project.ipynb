# %%
import numpy as np
import pandas as pd

# %%
skills_df = pd.read_excel('C:\\Users\\athar\\Big-Data-Project\\project_data\\2023-33\\skills.xlsx', sheet_name = 2, header = 1)

# %%
skills_df.head()
# Out:
#    2023 National Employment Matrix title 2023 National Employment Matrix code  \
# 0                 Total, all occupations                              00-0000
# 1                       Chief executives                              11-1011
# 2        General and operations managers                              11-1021
# 3                         Legislators[2]                              11-1031
# 4    Advertising and promotions managers                              11-2011
#
#    Employment, 2023  Employment, 2033  Employment change, numeric, 2023–33  \
# 0          167849.8          174589.0                               6739.2
# 1             313.9             331.1                                 17.2
# 2            3630.1            3840.5                                210.4
# 3              33.7              35.0                                  1.4
# 4              22.2              21.7                                 -0.6
#
#    Employment change, percent, 2023–33 Median annual wage, dollars, 2023[1]  \
# 0                                  4.0                                48060
# 1                                  5.5                               206680
# 2                                  5.8                               101280
# 3                                  4.1                                47290
# 4                                 -2.6                               131870
#
#   Typical education needed for entry  Adaptability  \
# 0                                  —           3.8
# 1                  Bachelor's degree           4.2
# 2                  Bachelor's degree           4.1
# 3                  Bachelor's degree           4.2
# 4                  Bachelor's degree           4.0
#
#    Computers and information technology  ...  Interpersonal  Leadership  \
# 0                                   3.0  ...            3.5         3.2
# 1                                   3.7  ...            4.0         4.5
# 2                                   3.5  ...            3.7         4.0
# 3                                   3.7  ...            4.0         4.5
# 4                                   3.6  ...            3.5         3.2
#
#    Mathematics  Mechanical  Physical strength and stamina  \
# 0          2.6         1.9                            2.2
# 1          3.3         1.5                            1.3
# 2          3.0         1.7                            1.7
# 3          3.3         1.5                            1.3
# 4          3.0         1.3                            1.3
#
#    Problem solving and decision making  Project management  Science  \
# 0                                  3.5                 2.7      1.7
# 1                                  4.6                 4.1      1.8
# 2                                  4.1                 3.6      1.7
# 3                                  4.6                 4.1      1.8
# 4                                  3.8                 3.1      1.4
#
#    Speaking and listening  Writing and reading
# 0                     3.2                  3.3
# 1                     4.0                  4.2
# 2                     3.5                  3.8
# 3                     4.0                  4.2
# 4                     3.9                  3.7
#
# [5 rows x 25 columns]

# %%
skills_df = skills_df.rename(columns = {"2023 National Employment Matrix title" : "Occupation","Typical education needed for entry" : "Education","Median annual wage, dollars, 2023[1]" : "Salary"})

# %%
skills_df = skills_df.drop(columns = ['2023 National Employment Matrix code','Employment, 2023','Employment, 2033','Employment change, numeric, 2023–33','Employment change, percent, 2023–33'])

# %%
skills_df.head()
# Out:
#                               Occupation  Salary          Education  \
# 0                 Total, all occupations   48060                  —
# 1                       Chief executives  206680  Bachelor's degree
# 2        General and operations managers  101280  Bachelor's degree
# 3                         Legislators[2]   47290  Bachelor's degree
# 4    Advertising and promotions managers  131870  Bachelor's degree
#
#    Adaptability  Computers and information technology  \
# 0           3.8                                   3.0
# 1           4.2                                   3.7
# 2           4.1                                   3.5
# 3           4.2                                   3.7
# 4           4.0                                   3.6
#
#    Creativity and innovation  Critical and analytical thinking  \
# 0                        2.7                               3.1
# 1                        3.5                               4.1
# 2                        3.1                               3.6
# 3                        3.5                               4.1
# 4                        3.5                               3.5
#
#    Customer service  Detail oriented  Fine motor  Interpersonal  Leadership  \
# 0               3.3              3.6         2.5            3.5         3.2
# 1               3.9              3.7         1.7            4.0         4.5
# 2               3.6              3.6         1.7            3.7         4.0
# 3               3.9              3.7         1.7            4.0         4.5
# 4               3.5              3.5         1.6            3.5         3.2
#
#    Mathematics  Mechanical  Physical strength and stamina  \
# 0          2.6         1.9                            2.2
# 1          3.3         1.5                            1.3
# 2          3.0         1.7                            1.7
# 3          3.3         1.5                            1.3
# 4          3.0         1.3                            1.3
#
#    Problem solving and decision making  Project management  Science  \
# 0                                  3.5                 2.7      1.7
# 1                                  4.6                 4.1      1.8
# 2                                  4.1                 3.6      1.7
# 3                                  4.6                 4.1      1.8
# 4                                  3.8                 3.1      1.4
#
#    Speaking and listening  Writing and reading
# 0                     3.2                  3.3
# 1                     4.0                  4.2
# 2                     3.5                  3.8
# 3                     4.0                  4.2
# 4                     3.9                  3.7

# %%
skills_df['Education'].unique()
# Out:
# array(['—', "Bachelor's degree", 'High school diploma or equivalent',
#        "Master's degree", "Associate's degree",
#        'Postsecondary nondegree award',
#        'No formal educational credential', 'Some college, no degree',
#        'Doctoral or professional degree', nan], dtype=object)

# %%
skills_df['Education'] = skills_df['Education'].fillna('0')

# %%
skills_df['Education'] = skills_df['Education'].map({'-' : 0, 'No formal educational credential' : 0,'High school diploma or equivalent' : 1, 'Some college, no degree' : 1, 'Postsecondary nondegree award' : 1,'Associate\'s degree' : 2, 'Bachelor\'s degree' : 3, 'Master\'s degree' : 4, 'Doctoral or professional degree' : 5})

# %%
skills_df.head()
# Out:
#                               Occupation  Salary  Education  Adaptability  \
# 0                 Total, all occupations   48060        NaN           3.8
# 1                       Chief executives  206680        3.0           4.2
# 2        General and operations managers  101280        3.0           4.1
# 3                         Legislators[2]   47290        3.0           4.2
# 4    Advertising and promotions managers  131870        3.0           4.0
#
#    Computers and information technology  Creativity and innovation  \
# 0                                   3.0                        2.7
# 1                                   3.7                        3.5
# 2                                   3.5                        3.1
# 3                                   3.7                        3.5
# 4                                   3.6                        3.5
#
#    Critical and analytical thinking  Customer service  Detail oriented  \
# 0                               3.1               3.3              3.6
# 1                               4.1               3.9              3.7
# 2                               3.6               3.6              3.6
# 3                               4.1               3.9              3.7
# 4                               3.5               3.5              3.5
#
#    Fine motor  Interpersonal  Leadership  Mathematics  Mechanical  \
# 0         2.5            3.5         3.2          2.6         1.9
# 1         1.7            4.0         4.5          3.3         1.5
# 2         1.7            3.7         4.0          3.0         1.7
# 3         1.7            4.0         4.5          3.3         1.5
# 4         1.6            3.5         3.2          3.0         1.3
#
#    Physical strength and stamina  Problem solving and decision making  \
# 0                            2.2                                  3.5
# 1                            1.3                                  4.6
# 2                            1.7                                  4.1
# 3                            1.3                                  4.6
# 4                            1.3                                  3.8
#
#    Project management  Science  Speaking and listening  Writing and reading
# 0                 2.7      1.7                     3.2                  3.3
# 1                 4.1      1.8                     4.0                  4.2
# 2                 3.6      1.7                     3.5                  3.8
# 3                 4.1      1.8                     4.0                  4.2
# 4                 3.1      1.4                     3.9                  3.7

# %%
skills_df = skills_df.dropna()

# %%
skills_df.head()
# Out:
#                               Occupation  Salary  Education  Adaptability  \
# 1                       Chief executives  206680        3.0           4.2
# 2        General and operations managers  101280        3.0           4.1
# 3                         Legislators[2]   47290        3.0           4.2
# 4    Advertising and promotions managers  131870        3.0           4.0
# 5                     Marketing managers  157620        3.0           4.0
#
#    Computers and information technology  Creativity and innovation  \
# 1                                   3.7                        3.5
# 2                                   3.5                        3.1
# 3                                   3.7                        3.5
# 4                                   3.6                        3.5
# 5                                   3.6                        3.4
#
#    Critical and analytical thinking  Customer service  Detail oriented  \
# 1                               4.1               3.9              3.7
# 2                               3.6               3.6              3.6
# 3                               4.1               3.9              3.7
# 4                               3.5               3.5              3.5
# 5                               3.7               3.5              3.4
#
#    Fine motor  Interpersonal  Leadership  Mathematics  Mechanical  \
# 1         1.7            4.0         4.5          3.3         1.5
# 2         1.7            3.7         4.0          3.0         1.7
# 3         1.7            4.0         4.5          3.3         1.5
# 4         1.6            3.5         3.2          3.0         1.3
# 5         1.7            3.5         3.8          3.1         1.1
#
#    Physical strength and stamina  Problem solving and decision making  \
# 1                            1.3                                  4.6
# 2                            1.7                                  4.1
# 3                            1.3                                  4.6
# 4                            1.3                                  3.8
# 5                            1.3                                  4.0
#
#    Project management  Science  Speaking and listening  Writing and reading
# 1                 4.1      1.8                     4.0                  4.2
# 2                 3.6      1.7                     3.5                  3.8
# 3                 4.1      1.8                     4.0                  4.2
# 4                 3.1      1.4                     3.9                  3.7
# 5                 3.3      1.3                     3.8                  3.7

# %%
skills_df.columns
# Out:
# Index(['Occupation', 'Salary', 'Education', 'Adaptability',
#        'Computers and information technology', 'Creativity and innovation',
#        'Critical and analytical thinking', 'Customer service',
#        'Detail oriented', 'Fine motor', 'Interpersonal', 'Leadership',
#        'Mathematics', 'Mechanical', 'Physical strength and stamina',
#        'Problem solving and decision making', 'Project management', 'Science',
#        'Speaking and listening', 'Writing and reading'],
#       dtype='object')

# %%
skill_names = ['Salary', 'Education', 'Adaptability',
       'Computers and information technology', 'Creativity and innovation',
       'Critical and analytical thinking', 'Customer service',
       'Detail oriented', 'Fine motor', 'Interpersonal', 'Leadership',
       'Mathematics', 'Mechanical', 'Physical strength and stamina',
       'Problem solving and decision making', 'Project management', 'Science',
       'Speaking and listening', 'Writing and reading']

# %%
skills_data = skills_df.drop(['Occupation','Salary'],axis=1)

# %%
skills_data.head()
# Out:
#    Education  Adaptability  Computers and information technology  \
# 1        3.0           4.2                                   3.7
# 2        3.0           4.1                                   3.5
# 3        3.0           4.2                                   3.7
# 4        3.0           4.0                                   3.6
# 5        3.0           4.0                                   3.6
#
#    Creativity and innovation  Critical and analytical thinking  \
# 1                        3.5                               4.1
# 2                        3.1                               3.6
# 3                        3.5                               4.1
# 4                        3.5                               3.5
# 5                        3.4                               3.7
#
#    Customer service  Detail oriented  Fine motor  Interpersonal  Leadership  \
# 1               3.9              3.7         1.7            4.0         4.5
# 2               3.6              3.6         1.7            3.7         4.0
# 3               3.9              3.7         1.7            4.0         4.5
# 4               3.5              3.5         1.6            3.5         3.2
# 5               3.5              3.4         1.7            3.5         3.8
#
#    Mathematics  Mechanical  Physical strength and stamina  \
# 1          3.3         1.5                            1.3
# 2          3.0         1.7                            1.7
# 3          3.3         1.5                            1.3
# 4          3.0         1.3                            1.3
# 5          3.1         1.1                            1.3
#
#    Problem solving and decision making  Project management  Science  \
# 1                                  4.6                 4.1      1.8
# 2                                  4.1                 3.6      1.7
# 3                                  4.6                 4.1      1.8
# 4                                  3.8                 3.1      1.4
# 5                                  4.0                 3.3      1.3
#
#    Speaking and listening  Writing and reading
# 1                     4.0                  4.2
# 2                     3.5                  3.8
# 3                     4.0                  4.2
# 4                     3.9                  3.7
# 5                     3.8                  3.7

# %%
from sklearn.metrics.pairwise import cosine_similarity

# skills_data = skills_data[skills_data[skill_names] == '-']

# skills_df[skill_names] = skills_df[skill_names].replace('-',0)
# skills_df[skill_names] = skills_df[skill_names].astype(float)

# skills_data = skills_df[skill_names]


# user_skills = [4.1, 3.4, 2.3, 2.5, 3.0, 3.8, 5.0, 4.5, 3.5, 5.0, 3.2, 4.8, 2.3, 2.5, 3.0, 3.8,4.3,3.5]
user_skills = []

for i in range(0,10):
    user_skills.append(np.random)
cosine_similarities = cosine_similarity([user_skills], skills_data.astype(float))


skills_df['Similarity'] = cosine_similarities[0]
recommended_occupations = skills_df[['Occupation', 'Similarity']].sort_values(by='Similarity', ascending=False)
recommended_occupations.head()
# Out:
#   Cell In[149], line 16
#     cosine_similarities = cosine_similarity([user_skills], skills_data.astype(float))
#     ^
# IndentationError: expected an indented block after 'for' statement on line 14
